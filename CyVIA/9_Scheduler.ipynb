# %%
# Schedular v1 Client side Windows
# scheduler_v2.py file is the updated scheduler

import schedule, time, os 
import time 

t = time.localtime()
current_time = time.strftime("%H:%M:%S", t)
print('\nScheduler started at', current_time)

def run_every_n_min_task(): # okay
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every n minute task at', current_time)
    os.system('cmd /c "python process_scanner_win.py"') # Running process scanner

def run_every_hour_task(): 
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting hourly task at', current_time) 

def run_daily_at_specific_time_task(): # okay
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting daily task at', current_time) 

def run_n_to_n_minutes_task(): # okay
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every n to n minutes task at', current_time)

def run_every_monday_task():
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every monday task at', current_time)

def run_every_tuesday_at_time_task():
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every tuesday task at', current_time)

# Every n minutes 
schedule.every(1).minutes.do(run_every_n_min_task) 

# Every hour 
# schedule.every().hour.do(run_every_hour_task) 
  
# Daily at specific time 
schedule.every().day.at("08:00").do(run_daily_at_specific_time_task) 

# After every n to n mins in between run work() 
# schedule.every(2).to(3).minutes.do(run_n_to_n_minutes_task) 
  
# Every monday 
# schedule.every().monday.do(run_every_monday_task) 
  
# Every tuesday at 18:00
# schedule.every().tuesday.at("18:00").do(run_every_tuesday_at_time_task) 
  
# Run forever 
while True: 
    # Checks whether a scheduled task is pending to run or not 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Scheduler started at 21:14:54
#
# ** Starting every n minute task at 21:15:54
#
# ** Starting every n minute task at 21:17:09
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e2ea21dc6a49> in <module>
#      60     # Checks whether a scheduled task is pending to run or not
#      61     schedule.run_pending()
# ---> 62     time.sleep(1)
#
# KeyboardInterrupt:

# %%
# Schedular v2 Client side - Win/MAC/Linux
import schedule, time, os
import time 

t = time.localtime()
current_time = time.strftime("%H:%M:%S", t)
print('\nScheduler started at', current_time)

def run_every_n_min_task(): # okay
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every n minute task at', current_time)
    os.system('python process_scanner_v2.py') # Running process scanner replace python with python3 where needed.

def run_every_hour_task(): 
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting hourly task at', current_time) 

def run_daily_at_specific_time_task(): # okay
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting daily task at', current_time) 

def run_n_to_n_minutes_task(): # okay
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every n to n minutes task at', current_time)

def run_every_monday_task():
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every monday task at', current_time)

def run_every_tuesday_at_time_task():
    t = time.localtime()
    current_time = time.strftime("%H:%M:%S", t)
    print('\n** Starting every tuesday task at', current_time)

# Every n minutes 
schedule.every(1).minutes.do(run_every_n_min_task) 

# Every hour 
# schedule.every().hour.do(run_every_hour_task) 
  
# Daily at specific time 
# schedule.every().day.at("16:32").do(run_daily_at_specific_time_task) 

# After every n to n mins in between run work() 
# schedule.every(2).to(3).minutes.do(run_n_to_n_minutes_task) 
  
# Every monday 
# schedule.every().monday.do(run_every_monday_task) 
  
# Every tuesday at 18:00
# schedule.every().tuesday.at("18:00").do(run_every_tuesday_at_time_task) 
  
# Run forever 
while True: 
    # Checks whether a scheduled task is pending to run or not 
    schedule.run_pending() 
    time.sleep(1)

# %%
safe_words = ['python', 'c++']
x = ["Microsoft Visual C++ 2013 x86 12.0.21005",  
     "platform-python-setuptools-39.2.0-6.el8.noarch", 
     "Python 3.7.7 Development Libraries (... 3.7.7150.0",     
     "libsamba-policy0-python3-4.11.5+git.161.74bc5e6ec8e-lp152.2.12.x86_64",     
     "samba-python3-4.11.5+git.161.74bc5e6ec8e-lp152.2.12.x86_64",
     "Adeel"]

# for i in x:
#     if 'c++' not in i.lower():
#         print(i)

for i in x:
    if not any(y in i.lower() for y in safe_words):
        print(i)

# a_string = "A string is more than its parts!"
# matches = ["more", "wholesome", "milk"]

# if any(x in a_string for x in matches):
# Out:
# Adeel
